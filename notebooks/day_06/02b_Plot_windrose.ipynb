# %%
# !pip install windrose
# Out:
# Requirement already satisfied: windrose in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (1.9.0)
# Requirement already satisfied: matplotlib>=3 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from windrose) (3.8.2)
# Requirement already satisfied: numpy>=1.21 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from windrose) (1.26.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from matplotlib>=3->windrose) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from matplotlib>=3->windrose) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from matplotlib>=3->windrose) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from matplotlib>=3->windrose) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from matplotlib>=3->windrose) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from matplotlib>=3->windrose) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from matplotlib>=3->windrose) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from matplotlib>=3->windrose) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\rifani\anaconda3\envs\grib-handle\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3->windrose) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from windrose import WindroseAxes

# %%
# Read the wind data from the CSV file
df = pd.read_csv('D:/Projects/fiji-training-2024/notebooks/day_06/sample_wind_fiji_subset.csv')

# %%
# Extract wind direction and wind speed
wind_direction = df['wind_dir']
wind_speed = df['wind_speed']

# %%
# Create a windrose plot
ax = WindroseAxes.from_ax()
ax.bar(wind_direction, wind_speed, normed=True, opening=0.8, edgecolor='white')

# Customize the plot (optional)
ax.set_legend()
plt.title('Windrose')

# Show the plot
plt.show()
