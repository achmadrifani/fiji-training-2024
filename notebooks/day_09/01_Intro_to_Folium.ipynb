# %% [markdown]
# # Developing Interactive Visualization I: Introduction to Folium
#
# ## Overview of Folium
# Folium is a powerful Python library for creating interactive maps. It leverages the Leaflet.js library and allows for the creation of maps with minimal code.
#
# <img src="https://miro.medium.com/v2/1*NmXTp8oWUgVuzQs1yeIO9w.png">
#
# ## Installing Folium
# To install Folium, use the following command:
# ```python
# !pip install folium

# %% [markdown]
# ## Creating a Simple Map

# %%
import folium

# Define the coordinates for Fiji
fiji_coords = [-17.7134, 178.0650]

# Create a map centered on Fiji
fiji_map = folium.Map(location=fiji_coords, zoom_start=7)

# Display the map
fiji_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c5fd722dd04087bdcb455f9e4cde76c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c5fd722dd04087bdcb455f9e4cde76c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c5fd722dd04087bdcb455f9e4cde76c = L.map(
#                 &quot;map_0c5fd722dd04087bdcb455f9e4cde76c&quot;,
#                 {
#                     center: [-17.7134, 178.065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b21dde78aa6d31cfe0beef512d951351 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b21dde78aa6d31cfe0beef512d951351.addTo(map_0c5fd722dd04087bdcb455f9e4cde76c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Exercise 1: Create a Basic Map
# - Create a map centered on a different location in Fiji.
# - Choose a different city or landmark in Fiji and create a map centered on that location.
# - Adjust the zoom level to show more or less detail.

# %% [markdown]
# ## Integrating Markers
# ### Adding Simple Markers
#
# We can add markers to highlight important locations in Fiji.

# %%
# Add a marker for Suva (the capital of Fiji)
folium.Marker(location=[-18.1416, 178.4419], popup="Suva").add_to(fiji_map)

# Add a marker for Nadi (a major city in Fiji)
folium.Marker(location=[-17.7766, 177.4350], popup="Nadi").add_to(fiji_map)

# Display the updated map
fiji_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_025c5712b30f47c0d90b78e336376a15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_025c5712b30f47c0d90b78e336376a15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_025c5712b30f47c0d90b78e336376a15 = L.map(
#                 &quot;map_025c5712b30f47c0d90b78e336376a15&quot;,
#                 {
#                     center: [-17.7134, 178.065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b31a2afd2b92381d569a426268c6c78e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b31a2afd2b92381d569a426268c6c78e.addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             tile_layer_b31a2afd2b92381d569a426268c6c78e.addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             var marker_15ac7ceaa2f99b9921fb81dae7a3d7df = L.marker(
#                 [-18.1416, 178.4419],
#                 {}
#             ).addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#         var popup_12f5c26fa2adb1bdeec19be3aaf3bcce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_817a0e89f86c2c769d18a8b2e7906ab0 = $(`&lt;div id=&quot;html_817a0e89f86c2c769d18a8b2e7906ab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Suva&lt;/div&gt;`)[0];
#                 popup_12f5c26fa2adb1bdeec19be3aaf3bcce.setContent(html_817a0e89f86c2c769d18a8b2e7906ab0);
#
#
#
#         marker_15ac7ceaa2f99b9921fb81dae7a3d7df.bindPopup(popup_12f5c26fa2adb1bdeec19be3aaf3bcce)
#         ;
#
#
#
#
#             var marker_55a9f374a03a13cba31eeb6422f32cd6 = L.marker(
#                 [-17.7766, 177.435],
#                 {}
#             ).addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#         var popup_7094ea6dc638eef7d4878239c7d08f8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93f1677416a457fae265b972eada4169 = $(`&lt;div id=&quot;html_93f1677416a457fae265b972eada4169&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nadi&lt;/div&gt;`)[0];
#                 popup_7094ea6dc638eef7d4878239c7d08f8a.setContent(html_93f1677416a457fae265b972eada4169);
#
#
#
#         marker_55a9f374a03a13cba31eeb6422f32cd6.bindPopup(popup_7094ea6dc638eef7d4878239c7d08f8a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Exercise 2: Add Multiple Markers
# - Add markers to at least three different locations on your map.
# - Choose three different locations in Fiji.
# - Add markers for each location.

# %% [markdown]
# ### Customizing Markers
#
# Markers can be customized with different icons and colors.

# %%
# Add a customized marker for Lautoka
folium.Marker(
    location=[-17.6167, 177.4500],
    popup="Lautoka",
    icon=folium.Icon(color='green', icon='info-sign')
).add_to(fiji_map)

# Display the updated map
fiji_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_025c5712b30f47c0d90b78e336376a15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_025c5712b30f47c0d90b78e336376a15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_025c5712b30f47c0d90b78e336376a15 = L.map(
#                 &quot;map_025c5712b30f47c0d90b78e336376a15&quot;,
#                 {
#                     center: [-17.7134, 178.065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b31a2afd2b92381d569a426268c6c78e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b31a2afd2b92381d569a426268c6c78e.addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             tile_layer_b31a2afd2b92381d569a426268c6c78e.addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             var marker_15ac7ceaa2f99b9921fb81dae7a3d7df = L.marker(
#                 [-18.1416, 178.4419],
#                 {}
#             ).addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#         var popup_12f5c26fa2adb1bdeec19be3aaf3bcce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_817a0e89f86c2c769d18a8b2e7906ab0 = $(`&lt;div id=&quot;html_817a0e89f86c2c769d18a8b2e7906ab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Suva&lt;/div&gt;`)[0];
#                 popup_12f5c26fa2adb1bdeec19be3aaf3bcce.setContent(html_817a0e89f86c2c769d18a8b2e7906ab0);
#
#
#
#         marker_15ac7ceaa2f99b9921fb81dae7a3d7df.bindPopup(popup_12f5c26fa2adb1bdeec19be3aaf3bcce)
#         ;
#
#
#
#
#             var marker_55a9f374a03a13cba31eeb6422f32cd6 = L.marker(
#                 [-17.7766, 177.435],
#                 {}
#             ).addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#         var popup_7094ea6dc638eef7d4878239c7d08f8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93f1677416a457fae265b972eada4169 = $(`&lt;div id=&quot;html_93f1677416a457fae265b972eada4169&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nadi&lt;/div&gt;`)[0];
#                 popup_7094ea6dc638eef7d4878239c7d08f8a.setContent(html_93f1677416a457fae265b972eada4169);
#
#
#
#         marker_55a9f374a03a13cba31eeb6422f32cd6.bindPopup(popup_7094ea6dc638eef7d4878239c7d08f8a)
#         ;
#
#
#
#
#             tile_layer_b31a2afd2b92381d569a426268c6c78e.addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             var marker_3a3e0f1bdd727cea71b65f3f6eba41bb = L.marker(
#                 [-17.6167, 177.45],
#                 {}
#             ).addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             var icon_b23bba65a60cb10fac20c35ff23fbe6a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3a3e0f1bdd727cea71b65f3f6eba41bb.setIcon(icon_b23bba65a60cb10fac20c35ff23fbe6a);
#
#
#         var popup_02f8d48af1aacbda23ae935d092d9525 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_435e235dfc07cd78d898beed61e0f928 = $(`&lt;div id=&quot;html_435e235dfc07cd78d898beed61e0f928&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lautoka&lt;/div&gt;`)[0];
#                 popup_02f8d48af1aacbda23ae935d092d9525.setContent(html_435e235dfc07cd78d898beed61e0f928);
#
#
#
#         marker_3a3e0f1bdd727cea71b65f3f6eba41bb.bindPopup(popup_02f8d48af1aacbda23ae935d092d9525)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Using Custom Images/Icons
# We can also use custom images or icons for markers. Let's add a marker with a custom icon from a PNG file.
#
# Note: Make sure the PNG file is available in your working directory or provide the correct path to the file.

# %%
# Path to the custom icon
custom_icon_path = "D:/Projects/fiji-training-2024/data/sun.png"

# Create a custom icon
custom_icon = folium.CustomIcon(icon_image=custom_icon_path, icon_size=(30, 30))

# Add a marker with the custom icon
folium.Marker(
    location=[-18.1234, 178.5678],
    popup="Custom Icon Marker",
    icon=custom_icon
).add_to(fiji_map)

# Display the updated map
fiji_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c5fd722dd04087bdcb455f9e4cde76c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c5fd722dd04087bdcb455f9e4cde76c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c5fd722dd04087bdcb455f9e4cde76c = L.map(
#                 &quot;map_0c5fd722dd04087bdcb455f9e4cde76c&quot;,
#                 {
#                     center: [-17.7134, 178.065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b21dde78aa6d31cfe0beef512d951351 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b21dde78aa6d31cfe0beef512d951351.addTo(map_0c5fd722dd04087bdcb455f9e4cde76c);
#
#
#             tile_layer_b21dde78aa6d31cfe0beef512d951351.addTo(map_0c5fd722dd04087bdcb455f9e4cde76c);
#
#
#             var marker_b3e0404bdd922e770a6a71307b7f5eb8 = L.marker(
#                 [-18.1234, 178.5678],
#                 {}
#             ).addTo(map_0c5fd722dd04087bdcb455f9e4cde76c);
#
#
#         var custom_icon_31c1b025bcfeffc302ae86077df3f3a7 = L.icon({&quot;iconSize&quot;: [30, 30], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_b3e0404bdd922e770a6a71307b7f5eb8.setIcon(custom_icon_31c1b025bcfeffc302ae86077df3f3a7);
#
#
#         var popup_f4aa6d8d739312acc07f3e8310c73061 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c0175e67dd4a5754d409b5b24a750b1 = $(`&lt;div id=&quot;html_6c0175e67dd4a5754d409b5b24a750b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Custom Icon Marker&lt;/div&gt;`)[0];
#                 popup_f4aa6d8d739312acc07f3e8310c73061.setContent(html_6c0175e67dd4a5754d409b5b24a750b1);
#
#
#
#         marker_b3e0404bdd922e770a6a71307b7f5eb8.bindPopup(popup_f4aa6d8d739312acc07f3e8310c73061)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Exercise 3: Customize Markers
# - Customize the markers by changing their icons and colors.
# - Use different icons and colors for each marker to differentiate them.
# <br>
# You can download icons from this website https://www.flaticon.com/

# %% [markdown]
# ### Adding Popups and Tooltips
#
# Popups and tooltips provide additional information when interacting with the markers.

# %%
# Add a marker with a popup and a tooltip for Labasa
folium.Marker(
    location=[-16.4333, 179.3667],
    popup="Labasa",
    tooltip="Click for more info"
).add_to(fiji_map)

# Display the updated map
fiji_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_025c5712b30f47c0d90b78e336376a15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_025c5712b30f47c0d90b78e336376a15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_025c5712b30f47c0d90b78e336376a15 = L.map(
#                 &quot;map_025c5712b30f47c0d90b78e336376a15&quot;,
#                 {
#                     center: [-17.7134, 178.065],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b31a2afd2b92381d569a426268c6c78e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b31a2afd2b92381d569a426268c6c78e.addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             tile_layer_b31a2afd2b92381d569a426268c6c78e.addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             var marker_15ac7ceaa2f99b9921fb81dae7a3d7df = L.marker(
#                 [-18.1416, 178.4419],
#                 {}
#             ).addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#         var popup_12f5c26fa2adb1bdeec19be3aaf3bcce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_817a0e89f86c2c769d18a8b2e7906ab0 = $(`&lt;div id=&quot;html_817a0e89f86c2c769d18a8b2e7906ab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Suva&lt;/div&gt;`)[0];
#                 popup_12f5c26fa2adb1bdeec19be3aaf3bcce.setContent(html_817a0e89f86c2c769d18a8b2e7906ab0);
#
#
#
#         marker_15ac7ceaa2f99b9921fb81dae7a3d7df.bindPopup(popup_12f5c26fa2adb1bdeec19be3aaf3bcce)
#         ;
#
#
#
#
#             var marker_55a9f374a03a13cba31eeb6422f32cd6 = L.marker(
#                 [-17.7766, 177.435],
#                 {}
#             ).addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#         var popup_7094ea6dc638eef7d4878239c7d08f8a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_93f1677416a457fae265b972eada4169 = $(`&lt;div id=&quot;html_93f1677416a457fae265b972eada4169&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nadi&lt;/div&gt;`)[0];
#                 popup_7094ea6dc638eef7d4878239c7d08f8a.setContent(html_93f1677416a457fae265b972eada4169);
#
#
#
#         marker_55a9f374a03a13cba31eeb6422f32cd6.bindPopup(popup_7094ea6dc638eef7d4878239c7d08f8a)
#         ;
#
#
#
#
#             tile_layer_b31a2afd2b92381d569a426268c6c78e.addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             var marker_3a3e0f1bdd727cea71b65f3f6eba41bb = L.marker(
#                 [-17.6167, 177.45],
#                 {}
#             ).addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             var icon_b23bba65a60cb10fac20c35ff23fbe6a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3a3e0f1bdd727cea71b65f3f6eba41bb.setIcon(icon_b23bba65a60cb10fac20c35ff23fbe6a);
#
#
#         var popup_02f8d48af1aacbda23ae935d092d9525 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_435e235dfc07cd78d898beed61e0f928 = $(`&lt;div id=&quot;html_435e235dfc07cd78d898beed61e0f928&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lautoka&lt;/div&gt;`)[0];
#                 popup_02f8d48af1aacbda23ae935d092d9525.setContent(html_435e235dfc07cd78d898beed61e0f928);
#
#
#
#         marker_3a3e0f1bdd727cea71b65f3f6eba41bb.bindPopup(popup_02f8d48af1aacbda23ae935d092d9525)
#         ;
#
#
#
#
#             tile_layer_b31a2afd2b92381d569a426268c6c78e.addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#             var marker_692c647c34c0c70af5361834615c0e34 = L.marker(
#                 [-16.4333, 179.3667],
#                 {}
#             ).addTo(map_025c5712b30f47c0d90b78e336376a15);
#
#
#         var popup_4d0f42d7abe2c5e53b27f96aab8f0b3f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4cbf6ab527b8f65b784f708695fe8c66 = $(`&lt;div id=&quot;html_4cbf6ab527b8f65b784f708695fe8c66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Labasa&lt;/div&gt;`)[0];
#                 popup_4d0f42d7abe2c5e53b27f96aab8f0b3f.setContent(html_4cbf6ab527b8f65b784f708695fe8c66);
#
#
#
#         marker_692c647c34c0c70af5361834615c0e34.bindPopup(popup_4d0f42d7abe2c5e53b27f96aab8f0b3f)
#         ;
#
#
#
#
#             marker_692c647c34c0c70af5361834615c0e34.bindTooltip(
#                 `&lt;div&gt;
#                      Click for more info
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/
