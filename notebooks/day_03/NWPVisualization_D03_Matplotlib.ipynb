# %% [markdown]
# # Maplotlib
# #### by : Alpon Sepriando
# #### email : alpon.sepriando@bmkg.go.id

# %% [markdown]
# *Matplotlib is a powerful plotting library in Python that can be used to visualize various types of data, including weather data*

# %% [markdown]
# ## Anatomy of a plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Plot Terminology
#
# | Term        | Description                                                                                  |
# |-------------|----------------------------------------------------------------------------------------------|
# | axis        | Axes of the graph that are typically x, y, and z (for 3D plots).                              |
# | title       | Title of the plot.                                                                            |
# | label       | Name for the axis (e.g. xlabel or ylabel).                                                    |
# | legend      | Legend for the plot.                                                                          |
# | tick label  | Text or values that are represented on the axis.                                              |
# | symbol      | Symbol for data point(s) (on a scatter plot) that can be presented with different shapes/colors. |
# | size        | Size of, for example, a point on a scatter plot. Also used for referring to the text sizes on a plot. |
# | linestyle   | The style how the line should be drawn. Can be solid or dashed, for example.                  |
# | linewidth   | The width of a line on a plot.                                                                |
# | alpha       | Transparency level of a filled element in a plot (values between 0.0 (fully transparent) and 1.0 (no transparency)). |
# | tick(s)     | Refers to the tick marks on a plot.                                                           |
# | annotation  | Refers to the text added to a plot.                                                           |
# | padding     | The distance between an (axis/tick) label and the axis.                                       |

# %%
# Plot real data
import pandas as pd

# Load the data
df = pd.read_csv('D:/Projects/fiji-training-2024/notebooks/day_03/V88054_obs_subdaily.csv',encoding='latin1',skiprows=[1])
df['datetime'] = pd.to_datetime(df['lsd']+" "+df['time'])
df.head()
# Out:
#   station_no         lsd   time  air_temp  wet_bulb  dew_point  rel_humidity  \
# 0     V88054  2014-01-01  00:00      24.7      24.5       24.4          98.0
# 1     V88054  2014-01-01  01:00      25.0       NaN       24.0           NaN
# 2     V88054  2014-01-01  02:00      25.0       NaN       24.0           NaN
# 3     V88054  2014-01-01  03:00      24.6      24.5       24.5          99.0
# 4     V88054  2014-01-01  04:00      25.0       NaN       25.0           NaN
#
#    rain_3h  msl_pres  wind_speed  wind_dir            datetime
# 0      0.0    1007.0         0.0       0.0 2014-01-01 00:00:00
# 1      0.0    1006.0         0.0       0.0 2014-01-01 01:00:00
# 2      0.0    1006.0         0.0       0.0 2014-01-01 02:00:00
# 3      0.0    1004.7         0.0       0.0 2014-01-01 03:00:00
# 4      0.0    1004.0         0.0       0.0 2014-01-01 04:00:00

# %%
import matplotlib.pyplot as plt

# Create a basic plot
x = df['datetime']
y = df['air_temp']
plt.plot(x,y)
plt.plot(x,df['dew_point'])

# Save the plot
plt.savefig('D:/Projects/fiji-training-2024/notebooks/day_03/airtemp_nausori.png')

# Show the plot
plt.show()

# %%
## Line Plots
import matplotlib.pyplot as plt

# Sample data
temp_sub = df_sub['air_temp']
date_sub = df_sub['datetime']

plt.figure(figsize=(12, 6))
plt.plot(date_sub, temp_sub, linestyle='-', color='b', label='Temperature (°C)')
plt.title("Nausori Air Temperature Variation 2021 - 2023")
plt.xlabel("Years")
plt.ylabel("Temperature (°C)")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Create subset of data
# df_sub = df.loc[df['datetime'].dt.year > 2020] # Select data from 2021 onwards

# df_sub = df.loc[(df['datetime'].dt.year >= 2016) & (df['datetime'].dt.year <= 2018)] # to select between to years

# df_sub = df.loc[(df['datetime'].dt.year == 2021) & (df['datetime'].dt.month == 1)] # to select year and month

df_sub = df.loc[df['datetime'].dt.year == 2021]
df_sub_temp = df_sub.loc[(df_sub['air_temp']>=32)]

df_sub_temp
# temp_sub = df_sub['air_temp']
# date_sub = df_sub['datetime']
# Out:
#       station_no         lsd   time  air_temp  wet_bulb  dew_point  \
# 61548     V88054  2021-01-08  12:00      32.0      26.0       23.4
# 61644     V88054  2021-01-12  12:00      33.0      26.6       23.9
# 61645     V88054  2021-01-12  13:00      32.5      26.6       24.2
# 61646     V88054  2021-01-12  14:00      32.5      25.5       22.4
# 61671     V88054  2021-01-13  15:00      32.0      25.5       22.6
# 61717     V88054  2021-01-15  13:00      32.1      26.0       23.4
# 61718     V88054  2021-01-15  14:00      32.7      26.6       24.1
# 61719     V88054  2021-01-15  15:00      32.0      26.0       23.4
# 61740     V88054  2021-01-16  12:00      32.4      26.6       24.2
# 61741     V88054  2021-01-16  13:00      32.5      26.6       24.2
# 61742     V88054  2021-01-16  14:00      32.5      26.0       23.2
# 61743     V88054  2021-01-16  15:00      32.6      25.6       22.5
# 61744     V88054  2021-01-16  16:00      32.5      26.0       23.2
# ...

# %%
## Scatter Plots
#The relationship between two variables.
import matplotlib.pyplot as plt

# First subset (2021)
temperature = df_sub['air_temp']
humidity = df_sub['rel_humidity']

# second subset (32 deg)
temperature_32 = df_sub_temp['air_temp']
humidity_32 = df_sub_temp['rel_humidity']

# plotting part
plt.figure(figsize=(10, 6))

# plot the first subset
plt.scatter(temperature, humidity, color='gray', label='Temperature °C')

# plot the second subset
plt.scatter(temperature_32, humidity_32, color='red')

plt.scatter(df_sub['air_temp'],df_sub['dew_point'],color='blue')

plt.title("Temperature vs. Humidity")
plt.xlabel("Temperature (°C)")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.show()

# %%
## Bar Charts
#comparing quantities across different categories.
import matplotlib.pyplot as plt

# Sample data
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
rainfall = [78, 60, 82, 75, 90, 100, 120, 110, 95, 80, 85, 70]

plt.figure(figsize=(12, 8))
plt.bar(months, rainfall, color='b')
plt.title("Average Monthly Rainfall")
plt.xlabel("Months")
plt.ylabel("Rainfall (mm)")
plt.grid(True)
plt.show()

# %%
## Histograms
#show the distribution of a dataset
import matplotlib.pyplot as plt
import numpy as np

# Sample data
wind_speed = np.random.normal(15, 5, 100)  # Mean = 15 km/h, Std = 5 km/h

plt.figure(figsize=(10, 6))
plt.hist(wind_speed, bins=10, color='g', edgecolor='black')
plt.title("Distribution of Daily Wind Speed")
plt.xlabel("Wind Speed (km/h)")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
# Out:
# [17.73941192  9.84563153 18.17164047 19.08469651 19.19542675 16.17861246
#  13.70293962  8.48017693 19.59184506 15.26873086  3.35151028 16.94141825
#  22.74693393 19.23012104 17.21509933 12.21852969 10.52121139 11.41275344
#  14.77313807 12.85393445 16.29035062 10.07803501 22.78816316  9.32787486
#  18.03998823  9.44447445 15.77140256 12.57904311 18.12772412 10.31055725
#  13.29434974  9.5222938  20.24027026  8.58093825 14.46240656 18.25587365
#  15.28704504 19.53017027 15.34592469 13.07057645 19.58122274 19.9595838
#  17.97167957 10.64874333 10.58533983 21.60799502 16.26987899 17.22665671
#  12.69128642 14.33468304 18.02624328 16.14520274 18.91476535 16.94709857
#   7.92399582 24.15180902 11.71505522 21.49220397 24.25102381 17.04152664
#  10.67432174 12.31389485 15.38310988 17.39756187 17.09222992 18.37455831
#  10.07409019 21.60596906 10.74059331 22.50673014 18.62887887  6.15387957
#   8.78963209 12.19918467 14.72583433 27.16479979 11.04996966 18.62197589
# ...

# %%
##Heatmaps
#useful for visualizing data over a grid.
#Heatmap of Temperature Over a Day, visualize how temperature varies over different times and days
import matplotlib.pyplot as plt
import numpy as np

# Sample data
hours = np.arange(0, 24)
days = np.arange(1, 8)
temperature = np.random.rand(7, 24) * 15 + 10  # Random temperatures between 10 and 25
print(temperature)

plt.figure(figsize=(12, 8))
plt.imshow(temperature, cmap='hot', interpolation='nearest', aspect='auto')
plt.colorbar(label='Temperature (°C)')
plt.xticks(ticks=np.arange(0, 24), labels=hours)
plt.yticks(ticks=np.arange(0, 7), labels=["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])
plt.title("Heatmap of Temperature Over a Day")
plt.xlabel("Hour of the Day")
plt.ylabel("Day of the Week")
plt.show()
# Out:
# [[13.47074931 10.86979567 14.20171228 15.76815374 24.41067145 19.24401426
#   20.55823334 10.90662408 24.83692114 24.02910863 17.76459014 18.07027019
#   18.28858863 12.8365337  19.24710966 16.19393425 23.35102969 14.0858305
#   24.63825711 14.94056669 14.99888833 22.28615642 18.9691833  16.56730887]
#  [14.72738901 19.59934162 12.63888426 17.82764133 17.37275759 20.62186745
#   21.88798776 15.07720735 18.06667055 10.06991067 24.14473997 16.1758941
#   20.01483268 24.49224034 24.01483718 16.88592042 14.07199019 16.92871337
#   11.05502383 23.168127   17.30130247 18.86207986 18.11875005 21.31359363]
#  [22.79574218 22.14626373 20.86565713 15.55836632 13.49088006 24.32047239
#   12.70051607 21.50101166 23.34880933 14.41585587 10.1861831  22.88390922
#   22.63278176 16.82564376 20.4480081  23.47164867 11.91689019 24.94266248
#   24.56898328 12.48721281 10.01647739 14.82661388 15.32237949 10.59596797]
#  [16.24968892 20.92252249 15.46751152 24.58003455 14.06988759 11.02260065
# ...

# %%
## Contour

import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
x = np.linspace(0, 10, 100)  # Longitude
y = np.linspace(0, 10, 100)  # Latitude
X, Y = np.meshgrid(x, y)

# Suppose the rainfall has a sinusoidal pattern
Z = np.sin(X) * np.cos(Y) * 20 + 50  # Rainfall data in mm

plt.figure(figsize=(10, 8))
contour = plt.contourf(X, Y, Z, levels=10, cmap='Blues')
plt.colorbar(contour, label='Rainfall (mm)')
plt.clabel(contour, inline=True, fontsize=8)
plt.title('Contour Plot of Rainfall')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
x = np.linspace(0, 10, 10)  # Longitude
y = np.linspace(0, 10, 10)  # Latitude
X, Y = np.meshgrid(x, y)

# Sample wind data
u = np.sin(X) * 25  # Wind speed in the x direction
v = np.cos(Y) * 30  # Wind speed in the y direction

plt.figure(figsize=(10, 8))
plt.barbs(X, Y, u, v, length=6, linewidth=1.5, color='blue')
plt.title('Wind Barb Plot')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
# Save the plot as an image file
plt.savefig('myplot.png')
plt.show()

# %% [markdown]
# #colormap
# ![image.png](attachment:image.png)

# %% [markdown]
# # *Subplots*

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
days = np.arange(1, 11)  # Days
temperature = np.random.randint(20, 35, size=10)  # Temperature data (°C)
precipitation = np.random.rand(10) * 20  # Precipitation data (mm)

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 8))

# Subplot 1: Temperature data
ax1.plot(days, temperature, marker='o', color='blue')
ax1.set_title('Temperature Variation')
ax1.set_xlabel('Day')
ax1.set_ylabel('Temperature (°C)')
ax1.grid(True)

# Subplot 2: Precipitation data
ax2.bar(days, precipitation, color='green')
ax2.set_title('Daily Precipitation')
ax2.set_xlabel('Day')
ax2.set_ylabel('Precipitation (mm)')
ax2.grid(True)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
